# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("itteration_154.csv")

# %%
data
# Out:
#     8  3.994496123  0.010003912  4.74072316  117.7723781    1.00  0
# 0   8     0.079771     0.043206   -1.669927    85.003707    1.00  0
# 1   8     3.993327     0.034116    1.194221    72.554020   13.60  1
# 2   8     0.581174     0.037195   -4.784813   134.846897   14.32  1
# 3   8     3.881218     0.025481    4.738082   135.910984   18.55  1
# 4   8     1.140053     0.019718   -6.299360    86.990098   19.73  1
# 5   8     1.523738     0.022870   -6.276477    71.846234   34.58  1
# 6   8     2.076515     0.026849    1.269206    49.725090   35.99  1
# 7   8     3.986392     0.037850    1.171808    89.899738   36.12  2
# 8   8     3.509820     0.009485   -6.280429   134.936683   36.26  2
# 9   8     1.050487     0.043850    4.742682    25.020856   55.98  2
# 10  8     1.159827     0.012353   -6.271663    49.246437   58.50  2
# 11  8     1.346074     0.048921    4.748824    71.513411   60.72  3
# 12  8     3.926813     0.009034   -6.274491    31.804723   60.82  3
# 13  8     3.964325     0.005469   -6.287834   105.321500   62.57  3
# 14  8     2.117576     0.013398   -0.267489   135.358095   69.23  3
# 15  8     2.237798     0.008074    4.730673   149.972153   72.53  3
# 16  8     3.960721     0.030796    1.872225   107.807156   72.74  3
# 17  8     0.504090     0.036448    1.088263    67.286024   81.65  3
# 18  8     0.762653     0.014906   -3.893992    90.960987   83.37  3
# 19  8     0.550136     0.029911   -3.768642    50.599911   84.14  4
# 20  8     0.327946     0.041269    2.105110   133.448726   84.30  4
# 21  8     0.688353     0.038347   -6.286992   136.184235   98.30  4
# 22  8     3.945497     0.011788    2.421211    65.798409  103.14  4
# 23  8     0.867496     0.018903   -6.224188    90.614489  107.68  4
# 24  8     3.987618     0.026316   -6.293102    50.202495  108.19  5
# 25  8     0.420694     0.038616    2.649738   108.594031  109.03  5
# 26  8     2.214986     0.034912    4.512794   149.982672  115.26  5
# 27  8     1.604735     0.015795   -6.288910   134.061062  118.37  5
# 28  8     0.017669     0.017304   -6.273563   109.182441  130.85  5
# 29  8     3.994055     0.048622    3.616506    70.102287  132.24  6
# 30  8     0.752992     0.048032   -5.674991   135.633857  133.36  6
# 31  8     1.559403     0.016267    4.726144    54.219265  140.91  6
# 32  8     3.360820     0.032061   -6.266282   133.831351  146.97  6
# 33  8     3.976703     0.044027   -6.274646   110.246027  155.97  6
# 34  8     1.801262     0.049869    2.313065   141.794477  156.13  7
# 35  8     1.886625     0.039483    4.740896    31.802737  156.77  7
# 36  8     1.126937     0.012362   -6.280174   100.393227  167.91  7
# 37  8     0.159350     0.021143    4.703754   135.269613  168.00  7
# 38  8     3.367064     0.006491   -0.526407    60.295874  168.00  7

# %%
acids = data["ACID"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ACID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/c3/w8pqt3q54hs6xqz6bmpg6xyc0000gn/T/ipykernel_21039/1067676760.py in <module>
# ----> 1 acids = data["ACID"].unique()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
# -> 3083                 raise KeyError(key) from err
#    3084
#    3085         if tolerance is not None:
#
# KeyError: 'ACID'

# %%
acids

# %%
def vol(n, mr, ro, acid):
    if acid == 'HCl':
        return (n/11.65)*1000
        
    elif acid == 'ClAA':
        return 'N/A'
    else:
        return (n*mr)/ro

def mass(n, mr, acid):
    if acid == 'ClAA':
        return n*mr
    else:
        return 'N/A'

# %%
mr ={'TFAA':114.023,
    'AA':60,
    'DClAA':128.94,
    'H2SO4': 98.079 ,
    'HNO3':63,
    'ClAA':94.5,
    'HCl':36.46}
ro ={'TFAA':1.49,
    'AA':1.05,
    'DClAA':1.5634,
    'H2SO4':1.83,
    'HNO3':1.51,
    'ClAA':1.58,
    'HCl':1.2}

# %%
acid_vol = []
acid_mass = []

# %%
for index, row in data.iterrows():
    v = vol(row["Acid_mol"], mr[row["ACID"]], ro[row["ACID"]], row["ACID"])
    acid_vol.append(v)
    m = mass(row["Acid_mol"], mr[row["ACID"]], row["ACID"])
    acid_mass.append(m)

# %%
acid_vol

# %%
data["Acid_V"] = acid_vol
data["Acid_mass"] = acid_mass

# %%
data.to_excel("data_acid_moles.xlsx")
