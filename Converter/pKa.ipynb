# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("DATA_water_updated.xlsx")
data
# Out:
#      Unnamed: 0 Experiment  DMF  H2O_vol  Acid_vol  Acid_pKa  ACID  \
# 0             0       4_13    8   1.5600      0.38      0.00  TFAA
# 1             1       4_13    8   0.8400      0.46      0.00  TFAA
# 2             2       4_13    8   1.4096      1.14     -6.30   HCl
# 3             3       4_13    8   1.4800      0.06      2.86  ClAA
# 4             4       4_13    8   3.4800      0.94      4.75    AA
# ..          ...        ...  ...      ...       ...       ...   ...
# 172         172       4_11    8   0.3200      0.50     -6.30   HCl
# 173         173       4_11    8   0.6400      1.00     -6.30   HCl
# 174         174       4_11    8   0.0640      0.10     -6.30   HCl
# 175         175       4_11    8   0.3200      0.50     -6.30   HCl
# 176         176       4_11    8   0.6400      1.00     -6.30   HCl
#
#      Temperature  Time_h_calc  %FA_formed(w/w)        SD  Acid_moles
# 0             60          3.0         0.099534  0.011640    0.004966
# ...

# %%
acids = data["ACID"].unique()

# %%
pka ={'TFAA':0,
    'AA':4.75,
    'DClAA':1.35,
    'H2SO4':-3,
    'HNO3':-1.37,
    'ClAA':2.86,
     'HCl':-6.3}

# %%
for index, row in data.iterrows():
    acid = row["ACID"]
    data.loc[index,['Acid_pKa']] = pka[acid]

# %%
data
# Out:
#      Unnamed: 0 Experiment  DMF  H2O_vol  Acid_vol  Acid_pKa  ACID  \
# 0             0       4_13    8   1.5600      0.38      0.00  TFAA
# 1             1       4_13    8   0.8400      0.46      0.00  TFAA
# 2             2       4_13    8   1.4096      1.14     -6.30   HCl
# 3             3       4_13    8   1.4800      0.06      2.86  ClAA
# 4             4       4_13    8   3.4800      0.94      4.75    AA
# ..          ...        ...  ...      ...       ...       ...   ...
# 172         172       4_11    8   0.3200      0.50     -6.30   HCl
# 173         173       4_11    8   0.6400      1.00     -6.30   HCl
# 174         174       4_11    8   0.0640      0.10     -6.30   HCl
# 175         175       4_11    8   0.3200      0.50     -6.30   HCl
# 176         176       4_11    8   0.6400      1.00     -6.30   HCl
#
#      Temperature  Time_h_calc  %FA_formed(w/w)        SD  Acid_moles
# 0             60          3.0         0.099534  0.011640    0.004966
# ...

# %%
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
data.to_excel("DATA_pKa_updated.xlsx")
